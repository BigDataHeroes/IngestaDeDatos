# %% [markdown]
# # Análisis exploratorio de los datos

# %%
import pandas as pd

# %%
datos = pd.read_csv('airbnb.csv', sep=',')
# Out:
# C:\Users\Carolina\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Visualización de los datos

# %%
datos.iloc[0:5,0:10]
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  19864  https://www.airbnb.com/rooms/19864  20180911024451   2018-09-11
# 1  21853  https://www.airbnb.com/rooms/21853  20180911024451   2018-09-11
# 2  24805  https://www.airbnb.com/rooms/24805  20180911024451   2018-09-11
# 3  24836  https://www.airbnb.com/rooms/24836  20180911024451   2018-09-11
# 4  26823  https://www.airbnb.com/rooms/26823  20180911024451   2018-09-11
#
#                                     name  \
# 0  PLAZA MAYOR  (wifi, air conditioning)
# 1                   Bright and airy room
# 2                 Gran Via Studio Madrid
# 3         Select the Madrid more "cool".
# 4                    Roon for two people
#
#                                              summary  \
# 0  Cosy small studio with a nice balcony close to...
# 1  We have a quiet and sunny room with a good vie...
# 2  Studio located 50 meters from Gran Via, next t...
# 3  Apartamento céntrico junto a Gran Vía (VT-296)...
# 4                                                NaN
#
#                                                space  \
# 0  THE PLACE: This small studio is located on the...
# 1  I am living in a nice flat near the centre of ...
# 2  LOCATION.  Brand new flats near the Atlantic H...
# 3  Select the Madrid more "cool" : 70 m, 2 bedroo...
# 4  Room for two person with dressing room and bat...
#
#                                          description experiences_offered  \
# 0  Cosy small studio with a nice balcony close to...                none
# 1  We have a quiet and sunny room with a good vie...                none
# 2  Studio located 50 meters from Gran Via, next t...                none
# 3  Select the Madrid more "cool" : 70 m, 2 bedroo...                none
# 4  Room for two person with dressing room and bat...                none
#
#                                neighborhood_overview
# 0  The studio is located in the city center at a ...
# 1  We live in a leafy neighbourhood with plenty o...
# 2  The area is next to the Gran Via, so people li...
# 3  Cosmopolita, lleno de locales de moda, restaur...
# 4                                                NaN

# %%
datos.iloc[0:5,10:20]
# Out:
#                                                notes  \
# 0  Late check in: please be aware that the person...
# 1  We are a 15 min bus ride away from the Casa de...
# 2                              Just enjoy your trip.
# 3  Al estar en el distrito Centro (Barrio de Just...
# 4                                                NaN
#
#                                              transit  \
# 0  Sol, Latina and Tirso de Molina metro stations...
# 1  The flat is near the centre of Madrid (15 minu...
# 2  To go from the airport you have several differ...
# 3  La situación del apartamento hace accesibles a...
# 4                                                NaN
#
#                                               access  \
# 0                                                NaN
# 1  There is fibre optic internet connection for y...
# 2  Apartment with elevator has a storage room for...
# 3  La disponibilidad de acceso al apartamento es ...
# 4                                                NaN
#
#                                          interaction  \
# 0  I will not be in the apartment waiting for you...
# 1  If I am at home and see each other around here...
# 2  I put at the disposal of my guests to facilita...
# 3  El precio marcado es por el alojamiento comple...
# 4                                                NaN
#
#                                          house_rules  thumbnail_url  \
# 0  Please do not forget to turn off the air condi...            NaN
# 1               Many thanks for not smoking at home.            NaN
# 2  During your stay it is your home. Feel it as i...            NaN
# 3  Esperamos que los huéspedes traten la casa com...            NaN
# 4  No smoking. No pets. Please leave the room in ...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/5351816/7f...
# 1         NaN  https://a0.muscache.com/im/pictures/68483181/8...
# 2         NaN  https://a0.muscache.com/im/pictures/71284479/b...
# 3         NaN  https://a0.muscache.com/im/pictures/573005/a2c...
# 4         NaN  https://a0.muscache.com/im/pictures/167976/3c5...
#
#    xl_picture_url  host_id
# 0             NaN    74966
# 1             NaN    83531
# 2             NaN   101471
# 3             NaN   101653
# 4             NaN   114340

# %%
datos.iloc[0:5,20:30]
# Out:
#                                    host_url host_name  host_since  \
# 0   https://www.airbnb.com/users/show/74966    Ismael  2010-01-29
# 1   https://www.airbnb.com/users/show/83531     Abdel  2010-02-21
# 2  https://www.airbnb.com/users/show/101471    Iraido  2010-03-31
# 3  https://www.airbnb.com/users/show/101653     Tenty  2010-03-31
# 4  https://www.airbnb.com/users/show/114340  Agustina  2010-04-27
#
#               host_location  \
# 0                    Espana
# 1     Madrid, Madrid, Spain
# 2     Madrid, Madrid, Spain
# 3  Las Rozas, Madrid, Spain
# 4     Madrid, Madrid, Spain
#
#                                           host_about  host_response_time  \
# 0  Hola! \r\n\r\nWelcome to Madrid! \r\n\r\nPleas...      within an hour
# 1  EN-ES-FR\r\nEN\r\nHi everybody: I'm Abdel. I'm...      within an hour
# 2  Me encanta tratar a mis clientes, como me gust...                 NaN
# 3  Mi mayor pasión es viajar y conocer culturas d...  within a few hours
# 4  I like Fine art, Photography, Cinema, travel a...  within a few hours
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 f
# 1               100%                   NaN                 f
# 2                NaN                   NaN                 f
# 3               100%                   NaN                 t
# 4               100%                   NaN                 t
#
#                                   host_thumbnail_url
# 0  https://a0.muscache.com/im/users/74966/profile...
# 1  https://a0.muscache.com/im/users/83531/profile...
# 2  https://a0.muscache.com/im/pictures/user/233f4...
# 3  https://a0.muscache.com/im/users/101653/profil...
# 4  https://a0.muscache.com/im/users/114340/profil...

# %%
datos.iloc[0:5,30:40]
# Out:
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/74966/profile...        Embajadores
# 1  https://a0.muscache.com/im/users/83531/profile...             Aluche
# 2  https://a0.muscache.com/im/pictures/user/233f4...           Malasaña
# 3  https://a0.muscache.com/im/users/101653/profil...           Justicia
# 4  https://a0.muscache.com/im/users/114340/profil...            Legazpi
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  2.0                        2.0
# 2                  2.0                        2.0
# 3                  1.0                        1.0
# 4                  2.0                        2.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1  ['email', 'phone', 'reviews', 'manual_offline'...                    t
# 2  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 3          ['email', 'phone', 'facebook', 'reviews']                    t
# 4  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
#
#   host_identity_verified                              street neighbourhood  \
# 0                      t               Madrid, Madrid, Spain   Embajadores
# 1                      t               Madrid, Madrid, Spain        Aluche
# 2                      t               Madrid, Madrid, Spain      Malasaña
# 3                      f  Madrid, Comunidad de Madrid, Spain      Justicia
# 4                      t  Madrid, Comunidad de Madrid, Spain       Legazpi
#
#   neighbourhood_cleansed
# 0            Embajadores
# 1               Cármenes
# 2            Universidad
# 3               Justicia
# 4                Legazpi

# %%
datos.iloc[0:5,40:50]
# Out:
#   neighbourhood_group_cleansed    city                state zipcode  market  \
# 0                       Centro  Madrid               Madrid   28012  Madrid
# 1                       Latina  Madrid               Madrid   28047  Madrid
# 2                       Centro  Madrid               Madrid   28004  Madrid
# 3                       Centro  Madrid  Comunidad de Madrid   28004  Madrid
# 4                   Arganzuela  Madrid  Comunidad de Madrid   28045  Madrid
#
#   smart_location country_code country   latitude  longitude
# 0  Madrid, Spain           ES   Spain  40.413418  -3.706838
# 1  Madrid, Spain           ES   Spain  40.403410  -3.740842
# 2  Madrid, Spain           ES   Spain  40.422022  -3.703954
# 3  Madrid, Spain           ES   Spain  40.419951  -3.697637
# 4  Madrid, Spain           ES   Spain  40.391161  -3.688234

# %%
datos.iloc[0:5,50:60]
# Out:
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 t     Apartment  Entire home/apt             2        1.0
# 1                 f     Apartment     Private room             1        1.0
# 2                 t     Apartment  Entire home/apt             3        1.0
# 3                 f     Apartment  Entire home/apt             4        1.0
# 4                 t        Hostel     Private room             2        1.0
#
#    bedrooms  beds       bed_type  \
# 0       0.0   1.0  Pull-out Sofa
# 1       1.0   1.0       Real Bed
# 2       0.0   2.0       Real Bed
# 3       2.0   3.0       Real Bed
# 4       1.0   1.0       Real Bed
#
#                                            amenities  square_feet
# 0  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...          NaN
# 1  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...         97.0
# 2  {TV,Internet,Wifi,"Air conditioning",Kitchen,E...          0.0
# 3  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN
# 4  {Internet,Wifi,"Wheelchair accessible",Doorman...          NaN

# %%
datos.iloc[0:5,60:70]
# Out:
#      price weekly_price monthly_price security_deposit cleaning_fee  \
# 0   $64.00          NaN       $750.00          $250.00       $30.00
# 1   $17.00       $98.00       $370.00              NaN          NaN
# 2   $60.00      $450.00     $1,200.00          $200.00       $30.00
# 3  $115.00      $600.00           NaN          $200.00        $0.00
# 4   $45.00          NaN           NaN          $150.00       $20.00
#
#    guests_included extra_people  minimum_nights  maximum_nights  \
# 0                1        $0.00               2             365
# 1                1        $8.00               4              40
# 2                2       $10.00               5             730
# 3                4        $0.00               3            1125
# 4                2       $50.00               2            1125
#
#   calendar_updated
# 0            today
# 1     2 months ago
# 2            today
# 3       4 days ago
# 4            today

# %%
datos.iloc[0:5,70:80]
# Out:
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                9               30               60
# 1                t                0                0               21
# 2                t                0                6               36
# 3                t                4               25               49
# 4                t               30               60               90
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0               148            2018-09-11                104   2012-05-07
# 1               296            2018-09-11                 33   2014-10-10
# 2               311            2018-09-11                  2   2014-11-29
# 3               323            2018-09-11                 46   2011-06-02
# 4               365            2018-09-11                 28   2010-09-28
#
#   last_review  review_scores_rating
# 0  2018-09-04                  91.0
# 1  2018-07-15                  92.0
# 2  2017-07-03                 100.0
# 3  2018-07-15                  98.0
# 4  2018-05-01                  87.0

# %%
datos.iloc[0:5,80:90]
# Out:
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                     9.0                        9.0                    9.0
# 1                     9.0                        9.0                   10.0
# 2                     8.0                        8.0                   10.0
# 3                    10.0                       10.0                   10.0
# 4                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                  9.0
# 1                         10.0                     8.0                  9.0
# 2                         10.0                    10.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                          9.0                     9.0                  9.0
#
#   requires_license license  jurisdiction_names instant_bookable
# 0                t     NaN                 NaN                t
# 1                t     NaN                 NaN                f
# 2                t     NaN                 NaN                f
# 3                t  VT-296                 NaN                f
# 4                t     NaN                 NaN                f

# %%
datos.iloc[0:5,90:100]
# Out:
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f                     moderate
# 4                        f                     flexible
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               1               1.35
# 1                               2               0.69
# 2                               2               0.04
# 3                               1               0.52
# 4                               2               0.29

# %%
datos.shape
# Out:
# (18045, 96)

# %% [markdown]
# ### Eliminación de columnas

# %%
datos = datos.iloc[:,37:68]

# %%
datos.shape
# Out:
# (18045, 31)

# %%
datos.head()
# Out:
#                                street neighbourhood neighbourhood_cleansed  \
# 0               Madrid, Madrid, Spain   Embajadores            Embajadores
# 1               Madrid, Madrid, Spain        Aluche               Cármenes
# 2               Madrid, Madrid, Spain      Malasaña            Universidad
# 3  Madrid, Comunidad de Madrid, Spain      Justicia               Justicia
# 4  Madrid, Comunidad de Madrid, Spain       Legazpi                Legazpi
#
#   neighbourhood_group_cleansed    city                state zipcode  market  \
# 0                       Centro  Madrid               Madrid   28012  Madrid
# 1                       Latina  Madrid               Madrid   28047  Madrid
# 2                       Centro  Madrid               Madrid   28004  Madrid
# 3                       Centro  Madrid  Comunidad de Madrid   28004  Madrid
# 4                   Arganzuela  Madrid  Comunidad de Madrid   28045  Madrid
#
#   smart_location country_code       ...        \
# 0  Madrid, Spain           ES       ...
# 1  Madrid, Spain           ES       ...
# 2  Madrid, Spain           ES       ...
# 3  Madrid, Spain           ES       ...
# 4  Madrid, Spain           ES       ...
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...          NaN   $64.00
# 1  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...         97.0   $17.00
# 2  {TV,Internet,Wifi,"Air conditioning",Kitchen,E...          0.0   $60.00
# 3  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $115.00
# 4  {Internet,Wifi,"Wheelchair accessible",Doorman...          NaN   $45.00
#
#   weekly_price monthly_price security_deposit  cleaning_fee  guests_included  \
# 0          NaN       $750.00          $250.00        $30.00                1
# 1       $98.00       $370.00              NaN           NaN                1
# 2      $450.00     $1,200.00          $200.00        $30.00                2
# 3      $600.00           NaN          $200.00         $0.00                4
# 4          NaN           NaN          $150.00        $20.00                2
#
#    extra_people  minimum_nights
# 0         $0.00               2
# 1         $8.00               4
# 2        $10.00               5
# 3         $0.00               3
# 4        $50.00               2
#
# [5 rows x 31 columns]

# %%
datos.describe()
# Out:
#            latitude     longitude  accommodates     bathrooms      bedrooms  \
# count  18045.000000  18045.000000  18045.000000  18025.000000  18041.000000
# mean      40.420241     -3.696740      3.326960      1.264105      1.357076
# std        0.020299      0.024292      2.021922      0.589262      0.872394
# min       40.326280     -3.863907      1.000000      0.000000      0.000000
# 25%       40.409800     -3.707678      2.000000      1.000000      1.000000
# 50%       40.418278     -3.701612      3.000000      1.000000      1.000000
# 75%       40.427380     -3.693515      4.000000      1.000000      2.000000
# max       40.562736     -3.544220     16.000000      8.000000     16.000000
#
#                beds  square_feet  guests_included  minimum_nights
# count  18018.000000   387.000000     18045.000000    18045.000000
# mean       2.032579   372.891473         1.705459        3.928401
# std        1.557360   575.916012         1.257113       18.761334
# min        0.000000     0.000000         1.000000        1.000000
# 25%        1.000000     0.000000         1.000000        1.000000
# 50%        2.000000    97.000000         1.000000        2.000000
# 75%        3.000000   624.000000         2.000000        3.000000
# max       50.000000  5167.000000        16.000000     1124.000000

# %% [markdown]
# ## Datos nulos

# %%
nas_dictionary = {"columns":[], "nas_count":[]}
for column in datos.columns:
    nas_dictionary["columns"].append(column)
    nas_dictionary["nas_count"].append(len(datos[column])-datos[column].count())
nas_dictionary
nas_dataframe = pd.DataFrame(nas_dictionary)
nas_dataframe
# Out:
#                          columns  nas_count
# 0                         street          0
# 1                  neighbourhood       1013
# 2         neighbourhood_cleansed          0
# 3   neighbourhood_group_cleansed          0
# 4                           city          1
# 5                          state        280
# 6                        zipcode        611
# 7                         market         39
# 8                 smart_location          0
# 9                   country_code          0
# 10                       country          0
# 11                      latitude          0
# 12                     longitude          0
# 13             is_location_exact          0
# 14                 property_type          0
# 15                     room_type          0
# 16                  accommodates          0
# 17                     bathrooms         20
# 18                      bedrooms          4
# 19                          beds         27
# 20                      bed_type          0
# 21                     amenities          0
# 22                   square_feet      17658
# 23                         price          0
# 24                  weekly_price      15650
# 25                 monthly_price      15790
# 26              security_deposit       6185
# 27                  cleaning_fee       4689
# 28               guests_included          0
# 29                  extra_people          0
# 30                minimum_nights          0

# %% [markdown]
# La variable *square_feet* apenas contiene datos así que la vamos a eliminar

# %%
datos = datos.drop(['square_feet'], axis=1)

# %% [markdown]
# ## Variables categóricas

# %% [markdown]
# Street

# %%
datos.street.value_counts()
# Out:
# Madrid, Comunidad de Madrid, Spain                       15176
# Madrid, Community of Madrid, Spain                        1445
# Madrid, Madrid, Spain                                      904
# Madrid, Spain                                              278
# Madrid, Spain, Spain                                       128
# Madrid Center, Madrid, Spain                                10
# Madrid , Madrid, Spain                                       9
# Madrid, Comunidad de Madrid, ES, Madrid, Spain               7
# MADRID, Spain, Spain                                         6
# MADRID, city, Spain                                          5
# MADRID, Madrid, Spain                                        5
# Pozuelo de Alarcón, Comunidad de Madrid, Spain               4
# madrid, Comunidad de Madrid, Spain                           3
# Centro, Madrid, Spain                                        3
# -centro, madrid, Spain                                       3
# Madrid, España, Spain                                        3
# MADRID, MADRID, Spain                                        3
# Madrid, MADRID, Spain                                        2
# La Fortuna, Comunidad de Madrid, Spain                       2
# Madrid, Comunidad de Madrid, ES, madrid, Spain               2
# Madrid, Communauté de Madrid, Spain                          2
# Madrid, 28, Spain                                            2
# 马德里, 马德里自治区, Spain                                           2
# Villalbilla, Comunidad de Madrid, Spain                      2
# madrid, madrid, Spain                                        2
# Madrid, Comunidad de Madrid , Atocha, Spain                  2
# Apartment 3-I, Madrid, Spain                                 2
# Madrid, Autonome Gemeinschaft Madrid, Spain                  2
# madrid, Madrid, Spain                                        2
# Madrid , Madrid capital, Spain                               1
# Tiemblo, Ávila, Castilla y León, Spain                       1
# Almería, Andalucía, Spain                                    1
# San Lázaro, Madrid, Spain                                    1
# Lavapies, Comunidad de Madrid, Spain                         1
# Chiva, Valencian Community, Spain                            1
# MADRID , CENTRO , Comunidad de Madrid, Spain                 1
# madrid , Spain                                               1
# Madrid , Community of Madrid, Spain                          1
# Pozuelo, Comunidad de Madrid, Spain                          1
# Córdoba, Andalucía, Spain                                    1
# Aravaca, Madrid, Spain                                       1
# Madrid, madrid, Spain                                        1
# Madrid, Comunidad de Madrid, ES, Madrid, Spain, Spain        1
#  Madrid, Madrid, Spain                                       1
# Madrid, Comunidad de Madrid, ES, Madrid España, Spain        1
# Madrid , Comunidad de Madrid, Spain                          1
# Puerta del Angel, Madrid, Spain                              1
# Centro, Madrid, Community of Madrid, Spain                   1
# Rivas-Vaciamadrid, Comunidad de Madrid, Spain                1
# villa verde bajo, madrid, Spain                              1
# ., Madrid, Spain                                             1
# las matas  madrid, Community of Madrid, Spain                1
# Lavapiés, Comunidad de Madrid, Spain                         1
# Chueca, Madrid, Community of Madrid, Spain                   1
# ES, Spain                                                    1
# Madrid, Comunidad de Madrid, ESPANA, Madrid, Spain           1
# \nDelicias, Madrid, Spain                                    1
# MADRID, spain, Spain                                         1
# Name: street, dtype: int64

# %% [markdown]
# Esta variable no aporta nada así que la eliminamos

# %%
datos = datos.drop(["street"], axis = 1)

# %%
datos.neighbourhood.value_counts()
# Out:
# Malasaña               1779
# Embajadores            1556
# La Latina              1515
# Sol                    1234
# Justicia               1035
# Cortes                  850
# Palacio                 782
# Carabanchel             509
# Aluche                  480
# Ciudad Lineal           451
# Argüelles               368
# Puente de Vallecas      339
# Palos do Moguer         313
# Goya                    286
# Trafalgar               268
# Recoletos               253
# Usera                   231
# Hortaleza               212
# Fuencarral-el Pardo     205
# San Blas                184
# Guindalera              184
# Delicias                182
# Pacifico                181
# Gaztambide              179
# Cuatro Caminos          170
# Almagro                 162
# Acacias                 161
# Arapiles                154
# Ibiza                   153
# Castellana              143
#                        ...
# Imperial                114
# Bellas Vistas           113
# Barajas                 112
# Villaverde              109
# Fuente del Berro        106
# Moncloa                 103
# Jerónimos                97
# Hispanoamérica           91
# Berruguete               91
# Moratalaz                85
# Almenara                 74
# Ciudad Jardin            73
# Adelfas                  71
# El Viso                  68
# Nueva España             65
# Valdeacederas            64
# Villa de Vallecas        57
# Vallehermosa             52
# Centro                   49
# Castilla                 43
# Legazpi                  40
# Vicálvaro                37
# Chamberí                 37
# El Tréntaiseis           34
# Estrella                 20
# Arganzuela               16
# Retiro                   14
# Atocha                   12
# Salamanca                 8
# Tetuán                    7
# Name: neighbourhood, Length: 65, dtype: int64

# %% [markdown]
# Esta columna contiene barrios que no existen oficialmente. Utilizaremos la columna neighbourhood_cleansed que contiene los barrios correctos

# %%
datos = datos.drop(["neighbourhood"], axis = 1)

# %%
datos.neighbourhood_cleansed.value_counts()
# Out:
# Embajadores         2632
# Universidad         1909
# Palacio             1487
# Sol                 1293
# Justicia            1067
# Cortes               909
# Palos de Moguer      328
# Trafalgar            313
# Goya                 311
# Argüelles            307
# Recoletos            272
# Puerta del Angel     252
# Guindalera           206
# Gaztambide           194
# Pacífico             189
# Acacias              183
# Arapiles             178
# Delicias             175
# Cuatro Caminos       175
# Almagro              173
# Lista                165
# Ibiza                158
# San Isidro           156
# Castellana           155
# Rios Rosas           142
# Chopera              141
# Ventas               138
# Prosperidad          133
# Castillejos          129
# Bellas Vistas        124
#                     ...
# Colina                21
# Abrantes              20
# Estrella              20
# Arcos                 18
# Canillejas            18
# La Paz                17
# San Cristobal         16
# Atocha                16
# Salvador              15
# Palomas               15
# Marroquina            14
# Vinateros             13
# Butarque              12
# Corralejos            12
# Apostol Santiago      12
# Ambroz                11
# Piovera               11
# Aeropuerto            10
# El Goloso             10
# Orcasitas              9
# Hellín                 8
# Amposta                7
# Cuatro Vientos         6
# El Plantío             5
# Pavones                4
# Santa Eugenia          4
# Fuentelareina          4
# Valdemarín             3
# El Pardo               3
# Horcajo                1
# Name: neighbourhood_cleansed, Length: 127, dtype: int64

# %%
barrios = pd.read_csv("Barrios.csv", sep=";")

# %%
for x in datos.neighbourhood_cleansed.unique():
    if x not in barrios["Nombre"].unique():
        print(x)
# Out:
# Cármenes
# Rios Rosas
# Los Angeles
# Aguilas
# Zofío
# Apostol Santiago
# San Cristobal
# Fuentelareina

# %%
datos.loc[datos.neighbourhood_cleansed == "Cármenes","neighbourhood_cleansed"] = "Los Cármenes"
datos.loc[datos.neighbourhood_cleansed == "Rios Rosas","neighbourhood_cleansed"] = "Ríos Rosas"
datos.loc[datos.neighbourhood_cleansed == "Los Angeles","neighbourhood_cleansed"] = "Los Ángeles"
datos.loc[datos.neighbourhood_cleansed == "Aguilas","neighbourhood_cleansed"] = "Las Águilas"
datos.loc[datos.neighbourhood_cleansed == "Zofío","neighbourhood_cleansed"] = "Zofio"
datos.loc[datos.neighbourhood_cleansed == "Apostol Santiago","neighbourhood_cleansed"] = "Apóstol Santiago"
datos.loc[datos.neighbourhood_cleansed == "San Cristobal","neighbourhood_cleansed"] = "San Cristóbal"
datos.loc[datos.neighbourhood_cleansed == "Fuentelareina","neighbourhood_cleansed"] = "Fuentelarreina"

# %%
 datos["neighbourhood_cleansed_index"] = datos.neighbourhood_cleansed.apply(lambda x: barrios[barrios.Nombre==x].iloc[0,0])

# %%
datos.head()
# Out:
#   neighbourhood_cleansed neighbourhood_group_cleansed    city  \
# 0            Embajadores                       Centro  Madrid
# 1           Los Cármenes                       Latina  Madrid
# 2            Universidad                       Centro  Madrid
# 3               Justicia                       Centro  Madrid
# 4                Legazpi                   Arganzuela  Madrid
#
#                  state zipcode  market smart_location country_code country  \
# 0               Madrid   28012  Madrid  Madrid, Spain           ES   Spain
# 1               Madrid   28047  Madrid  Madrid, Spain           ES   Spain
# 2               Madrid   28004  Madrid  Madrid, Spain           ES   Spain
# 3  Comunidad de Madrid   28004  Madrid  Madrid, Spain           ES   Spain
# 4  Comunidad de Madrid   28045  Madrid  Madrid, Spain           ES   Spain
#
#     latitude             ...               \
# 0  40.413418             ...
# 1  40.403410             ...
# 2  40.422022             ...
# 3  40.419951             ...
# 4  40.391161             ...
#
#                                            amenities    price weekly_price  \
# 0  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...   $64.00          NaN
# 1  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...   $17.00       $98.00
# 2  {TV,Internet,Wifi,"Air conditioning",Kitchen,E...   $60.00      $450.00
# 3  {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $115.00      $600.00
# 4  {Internet,Wifi,"Wheelchair accessible",Doorman...   $45.00          NaN
#
#   monthly_price  security_deposit  cleaning_fee  guests_included  \
# 0       $750.00           $250.00        $30.00                1
# 1       $370.00               NaN           NaN                1
# 2     $1,200.00           $200.00        $30.00                2
# 3           NaN           $200.00         $0.00                4
# 4           NaN           $150.00        $20.00                2
#
#    extra_people minimum_nights neighbourhood_cleansed_index
# 0         $0.00              2                           12
# 1         $8.00              4                          101
# 2        $10.00              5                           15
# 3         $0.00              3                           14
# 4        $50.00              2                           24
#
# [5 rows x 29 columns]

# %%
datos.neighbourhood_group_cleansed.value_counts()
# Out:
# Centro                   9297
# Salamanca                1215
# Chamberí                 1057
# Arganzuela                998
# Tetuán                    674
# Retiro                    599
# Latina                    522
# Carabanchel               521
# Moncloa - Aravaca         520
# Chamartín                 500
# Ciudad Lineal             474
# Puente de Vallecas        366
# Usera                     243
# Hortaleza                 225
# Fuencarral - El Pardo     218
# San Blas - Canillejas     203
# Barajas                   116
# Villaverde                112
# Moratalaz                  89
# Villa de Vallecas          57
# Vicálvaro                  39
# Name: neighbourhood_group_cleansed, dtype: int64

# %%
distritos = pd.read_csv("Distritos.csv", sep=";")

# %%
for x in datos.neighbourhood_group_cleansed.unique():
    if x not in distritos["Nombre"].unique():
        print(x)

# %%
datos["neighbourhood_group_cleansed_index"] = datos.neighbourhood_group_cleansed.apply(lambda x: distritos[distritos.Nombre==x].iloc[0,0])
datos.head()
# Out:
#   neighbourhood_cleansed neighbourhood_group_cleansed    city  \
# 0            Embajadores                       Centro  Madrid
# 1           Los Cármenes                       Latina  Madrid
# 2            Universidad                       Centro  Madrid
# 3               Justicia                       Centro  Madrid
# 4                Legazpi                   Arganzuela  Madrid
#
#                  state zipcode  market smart_location country_code country  \
# 0               Madrid   28012  Madrid  Madrid, Spain           ES   Spain
# 1               Madrid   28047  Madrid  Madrid, Spain           ES   Spain
# 2               Madrid   28004  Madrid  Madrid, Spain           ES   Spain
# 3  Comunidad de Madrid   28004  Madrid  Madrid, Spain           ES   Spain
# 4  Comunidad de Madrid   28045  Madrid  Madrid, Spain           ES   Spain
#
#     latitude                ...                    price weekly_price  \
# 0  40.413418                ...                   $64.00          NaN
# 1  40.403410                ...                   $17.00       $98.00
# 2  40.422022                ...                   $60.00      $450.00
# 3  40.419951                ...                  $115.00      $600.00
# 4  40.391161                ...                   $45.00          NaN
#
#   monthly_price security_deposit  cleaning_fee  guests_included  extra_people  \
# 0       $750.00          $250.00        $30.00                1         $0.00
# 1       $370.00              NaN           NaN                1         $8.00
# 2     $1,200.00          $200.00        $30.00                2        $10.00
# 3           NaN          $200.00         $0.00                4         $0.00
# 4           NaN          $150.00        $20.00                2        $50.00
#
#    minimum_nights neighbourhood_cleansed_index  \
# 0               2                           12
# 1               4                          101
# 2               5                           15
# 3               3                           14
# 4               2                           24
#
#   neighbourhood_group_cleansed_index
# 0                                  1
# 1                                 10
# 2                                  1
# 3                                  1
# 4                                  2
#
# [5 rows x 30 columns]

# %%
datos.city.value_counts()
# Out:
# Madrid                                 17945
# MADRID                                    20
# Madrid                                    12
# Madrid, Comunidad de Madrid, ES           11
# Madrid Center                             10
# madrid                                     7
# Pozuelo de Alarcón                         4
# Centro                                     3
# -centro                                    3
# Apartment 3-I                              2
# La Fortuna                                 2
# Villalbilla                                2
# 马德里                                        2
# San Lázaro                                 1
# \nDelicias                                 1
# .                                          1
# Puerta del Angel                           1
# las matas  madrid                          1
# Madrid, Comunidad de Madrid, ESPANA        1
# Lavapiés                                   1
# MADRID , CENTRO                            1
#  Madrid                                    1
# Aravaca                                    1
# Lavapies                                   1
# Almería                                    1
# Pozuelo                                    1
# Chiva                                      1
# Chueca, Madrid                             1
# Tiemblo                                    1
# villa verde bajo                           1
# Córdoba                                    1
# Rivas-Vaciamadrid                          1
# Centro, Madrid                             1
# madrid                                     1
# Name: city, dtype: int64

# %% [markdown]
# Esta variable no aporta nada así que la eliminamos

# %%
datos = datos.drop(["city"], axis=1)

# %%
datos.state.value_counts()
# Out:
# Comunidad de Madrid             15193
# Community of Madrid              1449
# Madrid                            949
# Spain                             134
# madrid                              9
# city                                5
# MADRID                              5
# España                              3
# 马德里自治区                              2
# Comunidad de Madrid , Atocha        2
# 28                                  2
# Communauté de Madrid                2
# Andalucía                           2
# Autonome Gemeinschaft Madrid        2
# Madrid capital                      1
# spain                               1
# Valencian Community                 1
# Madrid España                       1
# Ávila, Castilla y León              1
# Madrid, Spain                       1
# Name: state, dtype: int64

# %%
datos = datos.drop(["state"], axis=1)

# %%
datos.market.value_counts()
# Out:
# Madrid                   17999
# Other (International)        6
# Other (Domestic)             1
# Name: market, dtype: int64

# %%
datos = datos.drop(["market"], axis=1)

# %%
datos = datos.drop(["country_code"], axis=1)

# %%
datos = datos.drop(["country"], axis=1)

# %%
datos.head()
# Out:
#   neighbourhood_cleansed neighbourhood_group_cleansed zipcode smart_location  \
# 0            Embajadores                       Centro   28012  Madrid, Spain
# 1           Los Cármenes                       Latina   28047  Madrid, Spain
# 2            Universidad                       Centro   28004  Madrid, Spain
# 3               Justicia                       Centro   28004  Madrid, Spain
# 4                Legazpi                   Arganzuela   28045  Madrid, Spain
#
#     latitude  longitude is_location_exact property_type        room_type  \
# 0  40.413418  -3.706838                 t     Apartment  Entire home/apt
# 1  40.403410  -3.740842                 f     Apartment     Private room
# 2  40.422022  -3.703954                 t     Apartment  Entire home/apt
# 3  40.419951  -3.697637                 f     Apartment  Entire home/apt
# 4  40.391161  -3.688234                 t        Hostel     Private room
#
#    accommodates                ...                    price  weekly_price  \
# 0             2                ...                   $64.00           NaN
# 1             1                ...                   $17.00        $98.00
# 2             3                ...                   $60.00       $450.00
# 3             4                ...                  $115.00       $600.00
# 4             2                ...                   $45.00           NaN
#
#    monthly_price security_deposit cleaning_fee guests_included extra_people  \
# 0        $750.00          $250.00       $30.00               1        $0.00
# 1        $370.00              NaN          NaN               1        $8.00
# 2      $1,200.00          $200.00       $30.00               2       $10.00
# 3            NaN          $200.00        $0.00               4        $0.00
# 4            NaN          $150.00       $20.00               2       $50.00
#
#   minimum_nights neighbourhood_cleansed_index  \
# 0              2                           12
# 1              4                          101
# 2              5                           15
# 3              3                           14
# 4              2                           24
#
#   neighbourhood_group_cleansed_index
# 0                                  1
# 1                                 10
# 2                                  1
# 3                                  1
# 4                                  2
#
# [5 rows x 25 columns]

# %%
datos.smart_location.value_counts()
# Out:
# Madrid, Spain                                 17945
# MADRID, Spain                                    20
# Madrid , Spain                                   12
# Madrid, Comunidad de Madrid, ES, Spain           11
# Madrid Center, Spain                             10
# madrid, Spain                                     7
# Pozuelo de Alarcón, Spain                         4
# -centro, Spain                                    3
# Centro, Spain                                     3
# 马德里, Spain                                        2
# La Fortuna, Spain                                 2
# Apartment 3-I, Spain                              2
# Villalbilla, Spain                                2
# Lavapiés, Spain                                   1
# Centro, Madrid, Spain                             1
# Aravaca, Spain                                    1
# Madrid, Comunidad de Madrid, ESPANA, Spain        1
# Tiemblo, Spain                                    1
# Córdoba, Spain                                    1
# madrid , Spain                                    1
# Chueca, Madrid, Spain                             1
# ., Spain                                          1
# Puerta del Angel, Spain                           1
# San Lázaro, Spain                                 1
# Almería, Spain                                    1
# Rivas-Vaciamadrid, Spain                          1
# \nDelicias, Spain                                 1
# ES, Spain                                         1
# Lavapies, Spain                                   1
# Pozuelo, Spain                                    1
# MADRID , CENTRO , Spain                           1
# villa verde bajo, Spain                           1
#  Madrid, Spain                                    1
# Chiva, Spain                                      1
# las matas  madrid, Spain                          1
# Name: smart_location, dtype: int64

# %%
datos = datos.drop(["smart_location"], axis = 1)

# %%
datos.is_location_exact.value_counts()
# Out:
# t    11981
# f     6064
# Name: is_location_exact, dtype: int64

# %%
datos.loc[datos.is_location_exact == "t", "is_location_exact"] = 1
datos.loc[datos.is_location_exact == "f", "is_location_exact"] = 0

# %%
datos.property_type.value_counts()
# Out:
# Apartment                 14857
# House                       833
# Loft                        691
# Serviced apartment          444
# Condominium                 412
# Bed and breakfast           178
# Guest suite                 134
# Other                       133
# Hostel                      109
# Guesthouse                   44
# Casa particular (Cuba)       37
# Hotel                        37
# Boutique hotel               37
# Townhouse                    35
# Chalet                       26
# Camper/RV                     8
# Aparthotel                    7
# Villa                         4
# Tiny house                    4
# In-law                        2
# Hut                           2
# Bungalow                      2
# Earth house                   2
# Boat                          1
# Dome house                    1
# Dorm                          1
# Island                        1
# Farm stay                     1
# Barn                          1
# Resort                        1
# Name: property_type, dtype: int64

# %%
import numpy as np
unique_property_type = datos.property_type.unique()
datos["property_type_index"] = datos.property_type.apply(lambda pt: np.where(unique_property_type==pt)[0][0])

# %%
datos = datos.drop(["room_type", "accommodates", "bathrooms", "bedrooms", "beds", "bed_type", "amenities", "security_deposit", "cleaning_fee", "guests_included", "extra_people", "minimum_nights"], axis = 1)

# %%
money_columns = ["price", "weekly_price", "monthly_price"]
for column in money_columns:
    datos.loc[:, column] = datos[column].replace('[\$,]', '', regex=True).astype(float)

# %%
datos.loc[:, "zipcode"] = datos.zipcode.replace("\n", np.NaN, regex=True).astype('float')

# %%
datos.loc[:, "property_type"] = datos.property_type.astype('category')
datos.loc[:, "neighbourhood_group_cleansed"] = datos.neighbourhood_group_cleansed.astype('category')

# %%
datos.describe()
# Out:
#             zipcode      latitude     longitude  is_location_exact  \
# count  17433.000000  18045.000000  18045.000000       18045.000000
# mean   28009.554752     40.420241     -3.696740           0.663951
# std      427.535478      0.020299      0.024292           0.472369
# min     2815.000000     40.326280     -3.863907           0.000000
# 25%    28005.000000     40.409800     -3.707678           0.000000
# 50%    28012.000000     40.418278     -3.701612           1.000000
# 75%    28018.000000     40.427380     -3.693515           1.000000
# max    46370.000000     40.562736     -3.544220           1.000000
#
#               price  weekly_price  monthly_price  \
# count  18045.000000   2395.000000    2255.000000
# mean      86.090773    422.063466    1342.652772
# std      290.331007    336.581664    1086.377953
# min        8.000000     70.000000     250.000000
# 25%       35.000000    220.000000     700.000000
# 50%       60.000000    370.000000    1200.000000
# 75%       90.000000    500.000000    1650.000000
# max    10005.000000   7000.000000   25000.000000
#
#        neighbourhood_cleansed_index  neighbourhood_group_cleansed_index  \
# count                  18045.000000                        18045.000000
# mean                      47.133444                            4.381546
# std                       48.674172                            4.866735
# min                       11.000000                            1.000000
# 25%                       13.000000                            1.000000
# 50%                       16.000000                            1.000000
# 75%                       72.000000                            7.000000
# max                      215.000000                           21.000000
#
#        property_type_index
# count         18045.000000
# mean              0.896536
# std               2.435670
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max              29.000000

# %% [markdown]
# ## Histogramas antes de la limpieza

# %%
datos.columns
selected_columns = ['zipcode','property_type','neighbourhood_group_cleansed',
       'latitude', 'longitude', 'is_location_exact', 
       'price', 'weekly_price', 'monthly_price',
       'neighbourhood_cleansed_index', 'neighbourhood_group_cleansed_index',
       'property_type_index']

# %%
import matplotlib.pyplot as plt # para dibujar
# %matplotlib inline

plt.figure(figsize=(20, 40))
for i, column in enumerate(selected_columns):
    plt.subplot(7,2,i+1)
    if datos[column].dtype.name == 'category':
        datos[column].value_counts().plot(kind='bar')
    else:
        datos[column].plot.hist(alpha=0.5, grid = True)
    plt.xlabel(column)
plt.show()

# %% [markdown]
# ## Outliers

# %%
percentiles = datos.quantile([.01, .05, .25, .50, .75, .95, .99, 1])
percentiles
# Out:
#       zipcode   latitude  longitude  is_location_exact     price  \
# 0.01  28001.0  40.369009  -3.755985                0.0     14.00
# 0.05  28004.0  40.391278  -3.724020                0.0     19.00
# 0.25  28005.0  40.409800  -3.707678                0.0     35.00
# 0.50  28012.0  40.418278  -3.701612                1.0     60.00
# 0.75  28018.0  40.427380  -3.693515                1.0     90.00
# 0.95  28045.0  40.460283  -3.651408                1.0    191.00
# 0.99  28053.0  40.483524  -3.597429                1.0    407.28
# 1.00  46370.0  40.562736  -3.544220                1.0  10005.00
#
#       weekly_price  monthly_price  neighbourhood_cleansed_index  \
# 0.01         90.00          299.0                          11.0
# 0.05        120.00          380.0                          11.0
# 0.25        220.00          700.0                          13.0
# 0.50        370.00         1200.0                          16.0
# 0.75        500.00         1650.0                          72.0
# 0.95        900.30         3000.0                         154.0
# 0.99       1681.14         4656.0                         206.0
# 1.00       7000.00        25000.0                         215.0
#
#       neighbourhood_group_cleansed_index  property_type_index
# 0.01                                 1.0                  0.0
# 0.05                                 1.0                  0.0
# 0.25                                 1.0                  0.0
# 0.50                                 1.0                  0.0
# 0.75                                 7.0                  0.0
# 0.95                                15.0                  6.0
# 0.99                                20.0                 10.0
# 1.00                                21.0                 29.0

# %%
import json
from shapely.geometry import shape, Point
# depending on your version, use: from shapely.geometry import shape, Point

# load GeoJSON file containing sectors
with open('MADRID.geojson') as f:
    js = json.load(f)
for index, row in datos.loc[datos[ 'zipcode'] <  percentiles.loc[ 0.01, 'zipcode']].iterrows():
    # construct point based on lon/lat returned by geocoder
    point = Point(row['longitude'], row['latitude'])
    
    # check each polygon to see if it contains the point
    for feature in js['features']:
        polygon = shape(feature['geometry'])
        if polygon.contains(point):
            datos.loc[index, 'zipcode']=float(feature['properties']['COD_POSTAL'])

# %%
import json
from shapely.geometry import shape, Point
# depending on your version, use: from shapely.geometry import shape, Point

# load GeoJSON file containing sectors
with open('MADRID.geojson') as f:
    js = json.load(f)
for index, row in datos.loc[datos[ 'zipcode'] >=  percentiles.loc[ 1, 'zipcode']].iterrows():
    # construct point based on lon/lat returned by geocoder
    point = Point(row['longitude'], row['latitude'])
    # check each polygon to see if it contains the point
    for feature in js['features']:
        polygon = shape(feature['geometry'])
        if polygon.contains(point):
            datos.loc[index, 'zipcode']=float(feature['properties']['COD_POSTAL'])

# %%
datos.describe()
# Out:
#             zipcode      latitude     longitude  is_location_exact  \
# count  17433.000000  18045.000000  18045.000000       18045.000000
# mean   28016.327081     40.420241     -3.696740           0.663951
# std       79.431644      0.020299      0.024292           0.472369
# min    28001.000000     40.326280     -3.863907           0.000000
# 25%    28005.000000     40.409800     -3.707678           0.000000
# 50%    28012.000000     40.418278     -3.701612           1.000000
# 75%    28018.000000     40.427380     -3.693515           1.000000
# max    38034.000000     40.562736     -3.544220           1.000000
#
#               price  weekly_price  monthly_price  \
# count  18045.000000   2395.000000    2255.000000
# mean      86.090773    422.063466    1342.652772
# std      290.331007    336.581664    1086.377953
# min        8.000000     70.000000     250.000000
# 25%       35.000000    220.000000     700.000000
# 50%       60.000000    370.000000    1200.000000
# 75%       90.000000    500.000000    1650.000000
# max    10005.000000   7000.000000   25000.000000
#
#        neighbourhood_cleansed_index  neighbourhood_group_cleansed_index  \
# count                  18045.000000                        18045.000000
# mean                      47.133444                            4.381546
# std                       48.674172                            4.866735
# min                       11.000000                            1.000000
# 25%                       13.000000                            1.000000
# 50%                       16.000000                            1.000000
# 75%                       72.000000                            7.000000
# max                      215.000000                           21.000000
#
#        property_type_index
# count         18045.000000
# mean              0.896536
# std               2.435670
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max              29.000000

# %%
datos.loc[datos.price >=  percentiles.price.loc[ 0.99], 'price'] = percentiles.price.loc[0.99]

# %%
datos.loc[datos.weekly_price >=  percentiles.weekly_price.loc[ 0.99], 'weekly_price'] = percentiles.weekly_price[0.99]

# %%
datos.loc[datos.monthly_price >=  percentiles.monthly_price.loc[ 0.99], 'monthly_price'] = percentiles.monthly_price[0.99]

# %% [markdown]
# ## Datos nulos - limpieza

# %%
nas_dictionary = {"columns":[], "nas_count":[]}
for column in datos.columns:
    nas_dictionary["columns"].append(column)
    nas_dictionary["nas_count"].append(len(datos[column])-datos[column].count())
nas_dictionary
nas_dataframe = pd.DataFrame(nas_dictionary)
print('Total filas:',len(datos))
nas_dataframe
# Out:
# Total filas: 18045
#                                columns  nas_count
# 0               neighbourhood_cleansed          0
# 1         neighbourhood_group_cleansed          0
# 2                              zipcode        612
# 3                             latitude          0
# 4                            longitude          0
# 5                    is_location_exact          0
# 6                        property_type          0
# 7                                price          0
# 8                         weekly_price      15650
# 9                        monthly_price      15790
# 10        neighbourhood_cleansed_index          0
# 11  neighbourhood_group_cleansed_index          0
# 12                 property_type_index          0

# %%
import json
from shapely.geometry import shape, Point
# depending on your version, use: from shapely.geometry import shape, Point

# load GeoJSON file containing sectors
with open('MADRID.geojson') as f:
    js = json.load(f)
for index, row in datos.loc[datos[ 'zipcode'].isna()].iterrows():
    # construct point based on lon/lat returned by geocoder
    point = Point(row['longitude'], row['latitude'])
    # check each polygon to see if it contains the point
    for feature in js['features']:
        polygon = shape(feature['geometry'])
        if polygon.contains(point):
            datos.loc[index, 'zipcode']=float(feature['properties']['COD_POSTAL'])

# %%
for index, row in datos.loc[datos['weekly_price'].isna()].iterrows():
    datos.loc[index, 'weekly_price'] = datos.loc[index, 'price'] * 7

# %%
for index, row in datos.loc[datos['monthly_price'].isna()].iterrows():
    datos.loc[index, 'monthly_price'] = datos.loc[index, 'price'] * 30

# %%
import matplotlib.pyplot as plt # para dibujar
# %matplotlib inline

plt.figure(figsize=(20, 40))
for i, column in enumerate(selected_columns):
    plt.subplot(7,2,i+1)
    if datos[column].dtype.name == 'category':
        datos[column].value_counts().plot(kind='bar')
    else:
        datos[column].plot.hist(alpha=0.5, grid = True)
    plt.xlabel(column)
plt.show()

# %%
pd.plotting.scatter_matrix(datos, alpha=0.2, figsize=(20, 20), diagonal = 'kde')
plt.show()

# %%
datos.boxplot(column='price', by='neighbourhood_group_cleansed',figsize=(15,10), rot=45)

# %%
fig, axes = plt.subplots(11,2,figsize=(25,200)) # create figure and axes

for i, (k, gp) in enumerate(datos.groupby(by=['neighbourhood_group_cleansed'])):
    gp.boxplot(column='price', by='neighbourhood_cleansed', rot=45, ax=axes.flatten()[i])
    axes.flatten()[i].set_title(k)
    fig.suptitle("")
plt.show()

# %% [markdown]
# ## Guardar datos limpios

# %%
datos.to_csv(path_or_buf="airbnb_clean.csv", sep=",")
